# %%
from ultralytics import YOLO
import cv2
import gradio as gr
from PIL import Image, ImageDraw, ImageFont

model = YOLO("yolov8n.pt")


def get_font():
    # OS별로 적절한 폰트 객체 반환 (한글 지원)
    from PIL import ImageFont
    import platform
    
    font_size = 25
    
    try:
        if platform.system() == "Windows":
            return ImageFont.truetype("malgun.ttf", font_size)
        elif platform.system() == "Darwin":  # macOS
            return ImageFont.truetype("AppleGothic.ttf", font_size)
        else:  # Linux      
            return ImageFont.load_default(size=font_size)
    except IOError:
        # 폰트 파일이 없을 경우 기본 폰트 사용
        return ImageFont.load_default(size=font_size)

def detect_objects(image_array):

    image = Image.fromarray(image_array.copy())
    draw = ImageDraw.Draw(image)

    font = get_font()

    response = model(image_array)
    bounding_box_list = response[0].boxes.xyxy.cpu().numpy()
    confidence_list = response[0].boxes.conf.cpu().numpy()
    label_id_list = response[0].boxes.cls.cpu().numpy()
    label_list = response[0].names

    for bounding_box, confidence, label_index in zip(bounding_box_list, confidence_list, label_id_list):
        x1, y1, x2, y2 = bounding_box
        label_text = label_list[label_index]

        draw.rectangle([(x1, y1), (x2, y2)], outline="green", width=2)
        draw.text((x1 + 5, y1 + 5), text="{}({:.2f}%)".format(label_text, confidence * 100), fill="red", font=font)

    return image


with gr.Blocks() as demo:

    def stream_webcam(image_array):
        detected_image = detect_objects(image_array)
        return detected_image
    

    webcam_image = gr.Image(label="실시간 화면", sources="webcam", width=640, height=480, streaming=True)
    output_image = gr.Image(label="검출 화면", type="pil")

    webcam_image.stream(stream_webcam, inputs=[webcam_image], outputs=[output_image])

demo.launch()


# image = cv2.imread("C:/Users/USER/Downloads/ImageTaggingSample1-fd324157.jpg")
# image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# detect_objects(image)
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 0: 384x640 (no detections), 66.0ms
# Speed: 2.9ms preprocess, 66.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.5ms
# Speed: 1.9ms preprocess, 72.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.7ms
# Speed: 1.8ms preprocess, 68.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 72.8ms
# Speed: 2.7ms preprocess, 72.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.8ms
# Speed: 2.5ms preprocess, 79.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 61.6ms
# Speed: 2.8ms preprocess, 61.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 60.0ms
# Speed: 1.3ms preprocess, 60.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 62.4ms
# Speed: 1.6ms preprocess, 62.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 56.6ms
# Speed: 1.5ms preprocess, 56.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 52.7ms
# Speed: 1.5ms preprocess, 52.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 78.9ms
# Speed: 1.4ms preprocess, 78.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 58.1ms
# Speed: 1.8ms preprocess, 58.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 60.8ms
# Speed: 4.4ms preprocess, 60.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 87.2ms
# Speed: 1.6ms preprocess, 87.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 60.0ms
# Speed: 1.5ms preprocess, 60.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 60.5ms
# Speed: 1.3ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 81.7ms
# Speed: 1.4ms preprocess, 81.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 73.9ms
# Speed: 1.4ms preprocess, 73.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 82.8ms
# Speed: 1.6ms preprocess, 82.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 53.1ms
# Speed: 1.4ms preprocess, 53.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 58.2ms
# Speed: 1.9ms preprocess, 58.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 83.4ms
# Speed: 1.4ms preprocess, 83.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 57.4ms
# Speed: 1.6ms preprocess, 57.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 82.1ms
# Speed: 1.2ms preprocess, 82.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 85.4ms
# Speed: 1.6ms preprocess, 85.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 54.6ms
# Speed: 1.4ms preprocess, 54.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 60.3ms
# Speed: 1.5ms preprocess, 60.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 83.3ms
# Speed: 1.3ms preprocess, 83.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 57.1ms
# Speed: 1.4ms preprocess, 57.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 64.5ms
# Speed: 1.5ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 76.4ms
# Speed: 1.8ms preprocess, 76.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 62.2ms
# Speed: 1.5ms preprocess, 62.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 57.8ms
# Speed: 1.8ms preprocess, 57.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 54.3ms
# Speed: 1.3ms preprocess, 54.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 56.8ms
# Speed: 1.5ms preprocess, 56.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 82.1ms
# Speed: 1.5ms preprocess, 82.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 78.4ms
# Speed: 1.3ms preprocess, 78.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 90.4ms
# Speed: 1.6ms preprocess, 90.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 109.0ms
# Speed: 3.2ms preprocess, 109.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 108.2ms
# Speed: 1.9ms preprocess, 108.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 115.7ms
# Speed: 2.2ms preprocess, 115.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 117.7ms
# Speed: 1.8ms preprocess, 117.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 120.1ms
# Speed: 4.0ms preprocess, 120.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 101.5ms
# Speed: 2.2ms preprocess, 101.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 116.0ms
# Speed: 3.6ms preprocess, 116.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 136.9ms
# Speed: 3.5ms preprocess, 136.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 114.2ms
# Speed: 3.0ms preprocess, 114.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 134.0ms
# Speed: 2.8ms preprocess, 134.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 102.8ms
# Speed: 2.2ms preprocess, 102.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 100.8ms
# Speed: 2.5ms preprocess, 100.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 1 refrigerator, 123.7ms
# Speed: 4.4ms preprocess, 123.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 refrigerator, 127.4ms
# Speed: 5.1ms preprocess, 127.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 refrigerator, 148.3ms
# Speed: 4.4ms preprocess, 148.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 refrigerator, 1 vase, 113.5ms
# Speed: 5.4ms preprocess, 113.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 refrigerator, 1 vase, 150.3ms
# Speed: 2.3ms preprocess, 150.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 refrigerator, 1 vase, 143.8ms
# Speed: 3.6ms preprocess, 143.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 refrigerator, 1 vase, 115.0ms
# Speed: 3.1ms preprocess, 115.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 refrigerator, 1 vase, 101.4ms
# Speed: 1.9ms preprocess, 101.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 refrigerator, 1 teddy bear, 120.8ms
# Speed: 2.9ms preprocess, 120.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cat, 1 dog, 1 laptop, 149.5ms
# Speed: 2.8ms preprocess, 149.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cats, 1 donut, 1 refrigerator, 142.4ms
# Speed: 5.2ms preprocess, 142.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cats, 1 donut, 1 refrigerator, 147.6ms
# Speed: 1.4ms preprocess, 147.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cats, 1 donut, 1 refrigerator, 128.7ms
# Speed: 4.7ms preprocess, 128.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 refrigerator, 142.0ms
# Speed: 1.9ms preprocess, 142.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 donut, 1 book, 136.0ms
# Speed: 3.8ms preprocess, 136.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 donut, 1 book, 127.7ms
# Speed: 1.5ms preprocess, 127.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 donut, 1 book, 156.5ms
# Speed: 2.0ms preprocess, 156.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 refrigerator, 137.8ms
# Speed: 3.5ms preprocess, 137.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 141.6ms
# Speed: 2.1ms preprocess, 141.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 115.0ms
# Speed: 3.7ms preprocess, 115.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 123.7ms
# Speed: 4.0ms preprocess, 123.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 refrigerator, 168.8ms
# Speed: 4.0ms preprocess, 168.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 teddy bear, 113.0ms
# Speed: 2.7ms preprocess, 113.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cats, 1 tv, 1 vase, 137.9ms
# Speed: 4.1ms preprocess, 137.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cats, 1 tv, 1 vase, 165.0ms
# Speed: 4.0ms preprocess, 165.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dog, 1 tv, 1 teddy bear, 100.2ms
# Speed: 4.0ms preprocess, 100.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cats, 111.1ms
# Speed: 2.7ms preprocess, 111.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cats, 1 tv, 169.4ms
# Speed: 3.1ms preprocess, 169.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cats, 111.7ms
# Speed: 4.0ms preprocess, 111.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cats, 1 tv, 1 teddy bear, 134.0ms
# Speed: 2.9ms preprocess, 134.0ms inference, 12.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 1 laptop, 1 teddy bear, 113.2ms
# Speed: 2.9ms preprocess, 113.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cats, 1 tv, 1 refrigerator, 1 teddy bear, 156.0ms
# Speed: 1.9ms preprocess, 156.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cats, 1 tv, 1 refrigerator, 1 teddy bear, 117.4ms
# Speed: 1.7ms preprocess, 117.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 155.8ms
# Speed: 2.8ms preprocess, 155.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 117.4ms
# Speed: 2.0ms preprocess, 117.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cat, 1 tv, 122.5ms
# Speed: 4.0ms preprocess, 122.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cat, 1 tv, 156.6ms
# Speed: 2.0ms preprocess, 156.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 1 refrigerator, 141.5ms
# Speed: 2.3ms preprocess, 141.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 refrigerator, 137.5ms
# Speed: 4.6ms preprocess, 137.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 refrigerator, 142.5ms
# Speed: 3.4ms preprocess, 142.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 refrigerator, 139.8ms
# Speed: 3.7ms preprocess, 139.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 tv, 1 refrigerator, 135.1ms
# Speed: 3.8ms preprocess, 135.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cats, 1 refrigerator, 1 teddy bear, 124.1ms
# Speed: 1.5ms preprocess, 124.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 teddy bear, 122.8ms
# Speed: 2.2ms preprocess, 122.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 teddy bear, 117.2ms
# Speed: 3.3ms preprocess, 117.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 teddy bear, 159.2ms
# Speed: 1.4ms preprocess, 159.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 teddy bear, 136.5ms
# Speed: 1.4ms preprocess, 136.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 teddy bear, 123.9ms
# Speed: 2.1ms preprocess, 123.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 teddy bear, 115.1ms
# Speed: 2.3ms preprocess, 115.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 teddy bear, 117.3ms
# Speed: 3.4ms preprocess, 117.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 teddy bear, 109.8ms
# Speed: 3.7ms preprocess, 109.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 teddy bear, 171.4ms
# Speed: 4.0ms preprocess, 171.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 teddy bear, 120.7ms
# Speed: 5.2ms preprocess, 120.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cat, 1 teddy bear, 117.5ms
# Speed: 3.2ms preprocess, 117.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 refrigerator, 157.5ms
# Speed: 2.8ms preprocess, 157.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 refrigerator, 151.5ms
# Speed: 1.8ms preprocess, 151.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 112.7ms
# Speed: 2.0ms preprocess, 112.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 139.6ms
# Speed: 3.3ms preprocess, 139.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 107.1ms
# Speed: 2.1ms preprocess, 107.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 132.5ms
# Speed: 3.9ms preprocess, 132.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 111.5ms
# Speed: 5.1ms preprocess, 111.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 110.4ms
# Speed: 4.6ms preprocess, 110.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 140.1ms
# Speed: 2.2ms preprocess, 140.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 107.2ms
# Speed: 1.9ms preprocess, 107.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 161.1ms
# Speed: 4.3ms preprocess, 161.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 153.2ms
# Speed: 2.7ms preprocess, 153.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 108.6ms
# Speed: 2.0ms preprocess, 108.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 101.6ms
# Speed: 2.5ms preprocess, 101.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 106.7ms
# Speed: 2.1ms preprocess, 106.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 155.4ms
# Speed: 1.2ms preprocess, 155.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 118.5ms
# Speed: 3.0ms preprocess, 118.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 173.3ms
# Speed: 3.6ms preprocess, 173.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 119.6ms
# Speed: 6.0ms preprocess, 119.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 111.4ms
# Speed: 3.8ms preprocess, 111.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 101.4ms
# Speed: 2.1ms preprocess, 101.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 151.8ms
# Speed: 3.2ms preprocess, 151.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 108.3ms
# Speed: 2.1ms preprocess, 108.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 124.8ms
# Speed: 2.3ms preprocess, 124.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 95.4ms
# Speed: 1.9ms preprocess, 95.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
